# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
pd.read_csv('../data/gdp_per_capita.csv')
# Out:
#      Country or Area                                      Year        Value  \
# 0        Afghanistan                                      2019  2065.036398
# 1        Afghanistan                                      2018  2033.779002
# 2        Afghanistan                                      2017  2058.383832
# 3        Afghanistan                                      2016  2057.062164
# 4        Afghanistan                                      2015  2068.265904
# ...              ...                                       ...          ...
# 6865        Zimbabwe                                      1992  3054.889178
# 6866        Zimbabwe                                      1991  3426.598094
# 6867        Zimbabwe                                      1990  3324.348171
# 6868   footnoteSeqID                                  Footnote          NaN
# 6869               2  Excludes South Sudan after July 9, 2011.          NaN
#
#       Value Footnotes
# 0                 NaN
# ...

# %%
gdp_df= pd.Dataframe(gdp_per_capita.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-eae4d119d3ca> in <module>
# ----> 1 df = pd.DataFrame(data, columns = ['First Column Name','Second Column Name',...])
#
# NameError: name 'data' is not defined

# %%
gdp_df = pd.read_csv('../data/gdp_per_capita.csv')

# %%
gdp_df
# Out:
#      Country or Area                                      Year        Value  \
# 0        Afghanistan                                      2019  2065.036398
# 1        Afghanistan                                      2018  2033.779002
# 2        Afghanistan                                      2017  2058.383832
# 3        Afghanistan                                      2016  2057.062164
# 4        Afghanistan                                      2015  2068.265904
# ...              ...                                       ...          ...
# 6865        Zimbabwe                                      1992  3054.889178
# 6866        Zimbabwe                                      1991  3426.598094
# 6867        Zimbabwe                                      1990  3324.348171
# 6868   footnoteSeqID                                  Footnote          NaN
# 6869               2  Excludes South Sudan after July 9, 2011.          NaN
#
#       Value Footnotes
# 0                 NaN
# ...

# %%
gdp_df.drop('Value Footnotes', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-d6b77a6f436c> in <module>
# ----> 1 gdp_df.drop('Value Footnotes', axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
my_list = list(gdp_df)
print (my_list)
# Out:
# ['Country or Area', 'Year', 'Value']

# %%
gdp_df
# Out:
#      Country or Area                                      Year        Value
# 0        Afghanistan                                      2019  2065.036398
# 1        Afghanistan                                      2018  2033.779002
# 2        Afghanistan                                      2017  2058.383832
# 3        Afghanistan                                      2016  2057.062164
# 4        Afghanistan                                      2015  2068.265904
# ...              ...                                       ...          ...
# 6865        Zimbabwe                                      1992  3054.889178
# 6866        Zimbabwe                                      1991  3426.598094
# 6867        Zimbabwe                                      1990  3324.348171
# 6868   footnoteSeqID                                  Footnote          NaN
# 6869               2  Excludes South Sudan after July 9, 2011.          NaN
#
# [6870 rows x 3 columns]
